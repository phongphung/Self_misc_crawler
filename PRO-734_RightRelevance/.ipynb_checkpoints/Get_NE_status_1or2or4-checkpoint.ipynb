# %%
from psycopg2 import connect
import pandas as pd
import numpy as np
import requests
#import psycopg2
import psycopg2 as db

NE_DB = "dbname='rest_in_peace' user='dbo' host='10.0.0.137' password='sentifi'"
PROFILE_DB = "dbname='da0' user='dbw' host='da0.ssh.sentifi.com' password='sentifi.da0'"

def connect_postgres():
    try:
        conn = db.connect(NE_DB)
        print("Initialised Connection")
        return conn
    except:
        print "I am unable to connect to the database"

# %%
conn = connect_postgres()
cur = conn.cursor()
cur.execute("set statement_timeout to 30000000; select pg_sleep(2);")
query = """SELECT named_entity_id, status, name, shortname, legalname FROM "named_entity" WHERE status in ('1', '2', '4')"""
cur.execute(query)
temp = cur.fetchall()
temp = map(list, temp)
df = pd.DataFrame(temp)
df.columns = ['named_entity_id', 'status', 'name', 'shortname', 'legalname']
conn.close()
# Out:
# Initialised Connection

# %%
df
# Out:
#          named_entity_id  status                                name  \
# 0                 135320       3           Eline van Beek  (elinevb)
# 1                 137020       3  Jesper Tornbjerg (JesperTornbjerg)
# 2                 476334       1                    China Fin Market
# 3                  32627       1                 Shin-Nihon Tatemono
# 4                 765926       3                        TradingFloor
# 5                 511972       3                           Cam Ellis
# 6                 520313       3                               Nissa
# 7                1091239       3                         acnnewswire
# 8                  39124       1              Welcron Kangwon Co Ltd
# 9                  60827       1                                 KRW
# 10               1791394       2                           Mittagong
# 11                 41870       3                       Sarah Mishkin
# 12                 29832       1                  Ramsay Health Care
# 13               1814587       1                   San-Ai Oil Co Ltd
# 14                725313       1                Entertainment Sector
# 15               1815125       1                                SACO
# 16               1808730       1                   Agrowill Group AB
# 17                511973       3                         Lori Parker
# 18                511974       3                       Micheal Scott
# 19                520314       3                       Nissim Aciman
# 20                 16962       1               Hankuk Package Co Ltd
# 21                 21416       1           Korea Plasma Technology U
# 22               1815148       1                                 EIC
# 23                511977       3                     Tina Ann Graves
# 24                 39566       1           Woowon Development Co Ltd
# 25               1815155       1                               SABIC
# 26               1815158       1                                SVCP
# 27                511980       3                            Skhawaja
# 28                511981       3                         Replay Rayy
# 29                511982       3                               11u60
# ...                  ...     ...                                 ...
# 1621712          1132906       3                           Jama Jack
# 1621713          1586336       3                     Chandan Chawhan
# 1621714           954145       3                       Danielle Park
# 1621715          1469992       3                      Thales Barreto
# 1621716           752113       3
# 1621717          1539429       3                      enricka julien
# 1621718          1695864       3                                Mtl.
# 1621719          1451075       3                      Splooge McButt
# 1621720          1399529       3                    Anthony Marsland
# 1621721          1117843       3                      Stop Self Harm
# 1621722          1074247       3                         Brad Vooren
# 1621723          1691208       3                              Jessi♛
